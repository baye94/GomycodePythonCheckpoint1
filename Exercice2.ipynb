# %%
factorielle =1
print('Enter une valeur:');
valeurSaisi = int(input());
r=range(1,valeurSaisi+1)
for i in r:
    factorielle= factorielle*i
print(factorielle)
# Out:
# Enter une valeur:
#  5
# 120
