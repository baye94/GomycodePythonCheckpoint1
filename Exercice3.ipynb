# %%
lesDonnees = {}
valeurSaisi = int(input());
r = range(1 , valeurSaisi+1);
for i in r:
    lesDonnees[i]=i*i;
print(lesDonnees.items())
# Out:
#  4
# dict_items([(1, 1), (2, 4), (3, 9), (4, 16)])
